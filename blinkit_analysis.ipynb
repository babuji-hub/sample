# %%
print("blinkit analysis project")
# Out:
# blinkit analysis project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## "import raw data"

# %%
df=pd.read_excel(r"C:\Users\EliteBook\Downloads\New folder\Tableau BlinkIT Grocery Project U16955293080 (4).xlsx")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df[df['Outlet_Size']=='Small']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50          Regular         0.045464
# 13             FDS46        17.60          Regular         0.047257
# 15             FDP49         9.00          Regular         0.069089
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 8510           FDN58        13.80          Regular         0.056862
# 8513           FDH31        12.00          Regular         0.020407
# 8517           FDF53        20.75              reg         0.083607
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 11                 Dairy  144.1102            OUT046
# ...

# %%
df.Outlet_Size
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df.Outlet_Size.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
df.Outlet_Size.fillna('avg')
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          avg
# 4         High
#          ...
# 8518      High
# 8519       avg
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df.Outlet_Size.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
df.Outlet_Size.replace('nan','avg')
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df.Outlet_Size.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
df.Outlet_Size.dropna()
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 4         High
# 5       Medium
#          ...
# 8517     Small
# 8518      High
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 6113, dtype: object

# %%
df.Outlet_Size.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
df.Outlet_Size
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df.Outlet_Size.replace('NaN','avg')
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna('avg')

# %%
df.Outlet_Size
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          avg
# 4         High
#          ...
# 8518      High
# 8519       avg
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df.tail(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8521  Snack Foods  103.1332            OUT018                       2009
# 8522  Soft Drinks   75.4670            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 8521      Medium               Tier 3  Supermarket Type2          1845.5976
# 8522       Small               Tier 1  Supermarket Type1           765.6700

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1           3735.138

# %%
 ##df['Item_Outlet_Sales']= df['Item_Outlet_Sales'].replace('Item_Outlet_Sales','sales')
df.rename(columns={'Item_Outlet_Sales':'sales'}, inplace=True)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# sales                        float64
# dtype: object

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Fat_Content'].replace('LF','Low Fat')
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat',
                                                       'low fat':'Low Fat',
                                                       'reg':'Regular'})

# %%
print(df['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular']

# %%
## Business requirement....

# %%
## kpi's  requirement....

# %%
# Total sales
total_sales=df['sales'].sum()
total_sales
# Out:
# 18591125.4104

# %%
#df.sales 
df.sales.sum()
# Out:
# 18591125.4104

# %%
Total_sum=df['sales'].sum()
Total_sum
# Out:
# 18591125.4104

# %%
Total_count=df['sales'].count()
Total_count
# Out:
# 8523

# %%
Total_mean=df['sales'].mean()
Total_mean
# Out:
# 2181.288913575032

# %%
Total_max=df['sales'].max()
Total_max
# Out:
# 13086.9648

# %%
Total_min=df['sales'].min()
Total_min
# Out:
# 33.29

# %%
print(f"no of mean   {Total_mean  }  ")
print(f"no of max   {Total_max}  ")
print(f"no of min   {Total_min}  ")
print(f"no of count   {Total_count}  ")
print(f"no of sum   { Total_sum}  ")
# Out:
# no of mean   2181.288913575032
# no of max   13086.9648
# no of min   33.29
# no of count   8523
# no of sum   18591125.4104

# %%
## charts requirements....

# %%
## total sales by fat content...

# %%
#sales_by_fat=df.groupby("Item_Fat_Content")["sales"].sum()
#plt.pie(sales_by_fat, lables=sales_by_fat.index,
#         autopct='%.1f%%',
#         startangle=90)
#plt.title("sales by fat content")
#plt.axis("equal")
#plt.show()

sales_by_fat = df.groupby("Item_Fat_Content")["sales"].sum()

plt.pie(sales_by_fat,
        labels=sales_by_fat.index,
        autopct='%.1f%%',
        startangle=90)

plt.title("Sales by Fat Content")
plt.axis("equal")
plt.show()

# %%
## total sales by item type..

# %%
sales_by_type = df.groupby("Item_Type")["Item_Outlet_Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)

plt.xticks(rotation=90)
plt.xlabel("Item_Type")
plt.ylabel("Total Sales")
plt.title("Total Sales by Item Type")

for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height(),
             f'{bar.get_height():,.0f}',
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()
